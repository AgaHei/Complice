# %% [markdown]
# # Imports et chargement des données

# %%
# Importer les bibliothèques nécessaires

import faiss
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer

from langchain.vectorstores import FAISS
from langchain.schema import Document
from langchain.embeddings import OpenAIEmbeddings

import os
from dotenv import load_dotenv

# %%
# 📁 Chemins
embedding_path = "../data/embeddings/chunks_embeddings.npy"
metadata_path = "../data/ready_for_embedding/chunks_with_metadata.csv"  # Fichier avec les métadonnées enrichies

# Chargement
embeddings = np.load(embedding_path)
df_meta = pd.read_csv(metadata_path)

print(f"{embeddings.shape[0]} vecteurs chargés.")
print(f"{df_meta.shape[0]} métadonnées chargées.")
# Out:
# 6346 vecteurs chargés.
# 6346 métadonnées chargées.

# %%
# Inspection de la structure des métadonnées
print("Colonnes disponibles dans les métadonnées:")
print(df_meta.columns.tolist())
print(f"\nPremières lignes:")
print(df_meta.head())
print(f"\nTypes de données:")
print(df_meta.dtypes)
# Out:
# Colonnes disponibles dans les métadonnées:
# ['source', 'page', 'chunk_id', 'text', 'length', 'theme', 'niveau', 'type']
#
# Premières lignes:
#                                             source  page  \
# 0  100 idees pour enseigner les ha - Mehdi Liratni     2
# 1  100 idees pour enseigner les ha - Mehdi Liratni     3
# 2  100 idees pour enseigner les ha - Mehdi Liratni     4
# 3  100 idees pour enseigner les ha - Mehdi Liratni     5
# 4  100 idees pour enseigner les ha - Mehdi Liratni     6
#
#                                             chunk_id  \
# 0  100 idees pour enseigner les ha - Mehdi Liratn...
# 1  100 idees pour enseigner les ha - Mehdi Liratn...
# 2  100 idees pour enseigner les ha - Mehdi Liratn...
# 3  100 idees pour enseigner les ha - Mehdi Liratn...
# 4  100 idees pour enseigner les ha - Mehdi Liratn...
#
#                                                 text  length  \
# 0  Dr Mehdi Liratni Préface du Pr René Pry 100 ID...      18
# 1  La version numérique de cet ouvrage a été réal...      30
# 2  SOMMAIRE Préface Remerciements INTRODUCTION HA...     171
# 3  CHAPITRE II COMPÉTENCES SOCLES DU COMPORTEMENT...     212
# 4  Idée 26 Les 4 règles et objectifs importants d...     236
#
#                 theme    niveau        type
# 0  relations sociales    facile     inconnu
# 1             autisme    facile     inconnu
# 2  relations sociales  complexe  définition
# 3            émotions  complexe     méthode
# 4  relations sociales  complexe      action
#
# Types de données:
# source      object
# page         int64
# chunk_id    object
# text        object
# length       int64
# theme       object
# niveau      object
# type        object
# dtype: object

# %% [markdown]
# # Création de l’index FAISS

# %%
# Dimension des vecteurs
d = embeddings.shape[1]

# Index simple (Flat L2)
index = faiss.IndexFlatL2(d)

# Ajout des vecteurs
index.add(embeddings)

print(f"✅ Index FAISS créé avec {index.ntotal} vecteurs.")
# Out:
# ✅ Index FAISS créé avec 6346 vecteurs.

# %% [markdown]
# # Sauvegarde de l’index

# %%
# Sauvegarde de l'index FAISS pour une utilisation future
# L'index FAISS sert à la recherche rapide de similarité entre vecteurs (embeddings) et les futures requêtes.

faiss.write_index(index, "../data/embeddings/faiss_index.idx")
print("📦 Index sauvegardé.")
# Out:
# 📦 Index sauvegardé.

# %% [markdown]
# # Test de requête sémantique

# %%
# Recharger le modèle d'embedding
model = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

# Exemple de requête
query = "Comment reconnaître la jalousie chez quelqu'un ?"
query_vec = model.encode([query])

# Recherche dans l'index
k = 5  # nombre de résultats
D, I = index.search(query_vec, k)

# Affichage des résultats
for i in I[0]:
    print(f"\n🔹 Chunk ID: {df_meta.iloc[i]['chunk_id']}")
    print(f"📘 Source: {df_meta.iloc[i]['source']}")
    print(f"📄 Page: {df_meta.iloc[i]['page']}")
    print(f"🏷️ Thème: {df_meta.iloc[i]['theme']}")
    print(f"📝 Texte:\n{df_meta.iloc[i]['text'][:500]}...")
# Out:
# 🔹 Chunk ID: 100 idees pour enseigner les ha - Mehdi Liratni_p182_c1
# 📘 Source: 100 idees pour enseigner les ha - Mehdi Liratni
# 📄 Page: 182
# 🏷️ Thème: émotions
# 📝 Texte:
# De plus, une personne qui valide les émotions avec une attitude compatissante donne vraiment envie de se confier et d’écouter ses conseils par la suite. • Autorisez les « sorties en amoureux » sous condition de connaître...
#
# 🔹 Chunk ID: 100 idees pour enseigner les ha - Mehdi Liratni_p181_c1
# 📘 Source: 100 idees pour enseigner les ha - Mehdi Liratni
# 📄 Page: 181
# 🏷️ Thème: relations sociales
# 📝 Texte:
# L’empathie est souvent un bon moyen de ne pas étouffer l’autre. Nous les encouragerons aussi à développer des centres d’intérêt (activités) solitaires pour qu’ils ne se sentent pas dépendants des autres. D’autres jeunes, au contraire, par crainte du lien affectif, vont plutôt se comporter de manière « évitante » et ne parviendront pas à créer d’intimité par crainte d’être trahis ou déçus. En les félicitant pour leur prudence, il faudra néanmoins les encourager à choisir au moins une personne dig...
#
# 🔹 Chunk ID: 683956044-Le-Syndrome-dAsperger-Guide-Complet_p35_c2
# 📘 Source: 683956044-Le-Syndrome-dAsperger-Guide-Complet
# 📄 Page: 35
# 🏷️ Thème: relations sociales
# 📝 Texte:
# Le mécanisme de compensation par l’arrogance peut affecter éga- lement d’autres aspects de l’interaction sociale. L’enfant peut avoir des difﬁ cultés à admettre son erreur et être fâcheusement réputé pour sa tendance à se disputer. Hans Asperger a conseillé :...
#
# 🔹 Chunk ID: 683956044-Le-Syndrome-dAsperger-Guide-Complet_p44_c1
# 📘 Source: 683956044-Le-Syndrome-dAsperger-Guide-Complet
# 📄 Page: 44
# 🏷️ Thème: relations sociales
# 📝 Texte:
# – Dissiper les appréhensions des autres diagnostics et du fait d’être fou. – Être reconnu comme ayant de véritables difﬁ cultés pour faire face aux expériences que les autres trouvent faciles et agréables. – Un changement positif dans les attentes des autres, pour être accepté et soutenu. – Des compliments plutôt que des critiques eu égard aux compé- tences sociales. – Reconnaissance de la confusion et de l’épuisement dans les situations sociales....
#
# 🔹 Chunk ID: Etre autiste et ado_ Strategies - Inconnu(e)_p165_c0
# 📘 Source: Etre autiste et ado_ Strategies - Inconnu(e)
# 📄 Page: 165
# 🏷️ Thème: émotions
# 📝 Texte:
# RÉAGIR, ça veut dire tenir compte des intentions et des émotions de l’autre dans ta réponse. TRUCS POUR BIEN ÉCOUTER ET RÉAGIR LORSQUE C’EST L’AUTRE QUI PARLE • Regarde l’autre le plus souvent possible (même si tu n’y gagnes pas beaucoup). Si, comme moi, tu écoutes mieux quand tu ne regardes pas vers le visage de l’autre, tu peux l’aviser que tu l’écoutes quand même pour ne pas qu’il pense que tu n’es pas intéressé....

# %% [markdown]
# # Suite du test de la recherche sémantique - plusieures questions

# %%
# Tests avec différentes questions

# Recharger le modèle
model = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

# Liste des questions à tester
queries = [
    "Comment réagir quand quelqu'un me fait une remarque blessante ?",
    "Pourquoi certaines personnes évitent le contact visuel ?",
    "Qu'est-ce que la joie et comment la reconnaître chez soi ?",
    "Comment se faire des amis quand on est timide ou différent ?",
    "Est-ce normal de ne pas comprendre les blagues ?"
]

# Nombre de résultats par requête
k = 3  # Réduisons à 3 pour plus de lisibilité

# Boucle sur les requêtes
for query in queries:
    print(f"\n🔍 Question : {query}")
    query_vec = model.encode([query])
    D, I = index.search(query_vec, k)

    for rank, i in enumerate(I[0]):
        chunk = df_meta.iloc[i]
        print(f"\n  🔹 Résultat {rank + 1}")
        print(f"  📘 Source : {chunk['source']}")
        print(f"  📄 Page : {chunk['page']}")
        print(f"  🏷️ Thème : {chunk['theme']}")
        print(f"  🎯 Type : {chunk['type']}")
        print(f"  📚 Niveau : {chunk['niveau']}")
        print(f"  📝 Texte :\n  {chunk['text'][:300]}...\n  ---")
# Out:
# 🔍 Question : Comment réagir quand quelqu'un me fait une remarque blessante ?
#
#   🔹 Résultat 1
#   📘 Source : Être autiste et réussir sa vie - Sherman Sezibera
#   📄 Page : 39
#   🏷️ Thème : autisme
#   🎯 Type : méthode
#   📚 Niveau : complexe
#   📝 Texte :
#   Je vais dire les choses telles que je les sens, telles que je les pense, à l’état brut. Je suis incapable d’autre chose. De votre côté, si vous vivez un malentendu avec une personne, vous pouvez régler la situation avec une certaine diplomatie. Vous allez peut-être tourner autour du pot ou ramener l...
#   ---
#
#   🔹 Résultat 2
#   📘 Source : 100 idees pour enseigner les ha - Mehdi Liratni
#   📄 Page : 220
#   🏷️ Thème : relations sociales
#   🎯 Type : inconnu
#   📚 Niveau : intermédiaire
#   📝 Texte :
#   c’est une gare ou un métro), demander à un passant, appeler le service client en cherchant sur internet… – Si je suis agressé verbalement ou physiquement : crier « à l’aide, au secours », s’enfuir, se rapprocher d’un groupe et leur expliquer la situation, aller vers les employés (contrôleurs, chauff...
#   ---
#
#   🔹 Résultat 3
#   📘 Source : Être autiste et réussir sa vie - Sherman Sezibera
#   📄 Page : 8
#   🏷️ Thème : relations sociales
#   🎯 Type : explication
#   📚 Niveau : complexe
#   📝 Texte :
#   Que peut me faire votre opinion? Un fouillis de pensées, un amas de mots. Tout peut changer à tout moment. Au lieu de cela, je me tais et j’observe. C’est ce que je fais le mieux: observer. C’est ainsi que j’apprends. Je vous regarde faire, je vous écoute. Ce n’est pas pour être impolie, mais parfoi...
#   ---
#
# 🔍 Question : Pourquoi certaines personnes évitent le contact visuel ?
#
#   🔹 Résultat 1
#   📘 Source : 683956044-Le-Syndrome-dAsperger-Guide-Complet
#   📄 Page : 112
#   🏷️ Thème : relations sociales
#   🎯 Type : exemple
#   📚 Niveau : complexe
#   📝 Texte :
#   97 Compréhension sociale et amitié sions faciales, je recommande d’expliquer pourquoi la personne évite le contact visuel : par exemple, « J’ai besoin de regarder ailleurs pour me concentrer et bien répondre à votre question. Je ne suis pas malpoli, malhonnête, et ne manque pas de respect ». Lorsque...
#   ---
#
#   🔹 Résultat 2
#   📘 Source : Penser-en-images_9782738143129
#   📄 Page : 30
#   🏷️ Thème : relations sociales
#   🎯 Type : exemple
#   📚 Niveau : complexe
#   📝 Texte :
#   essentiellement visuels ; ils ne traitent pas tous l’informa- tion de cette façon. Les êtres humains se placent sur un continuum d’aptitude visuelle, qui va d’une capacité quasi nulle, c’est-à-dire de la visualisation d’images vagues et générales, jusqu’à la vision d’images très précises comme dans ...
#   ---
#
#   🔹 Résultat 3
#   📘 Source : Penser-en-images_9782738143129
#   📄 Page : 58
#   🏷️ Thème : autisme
#   🎯 Type : inconnu
#   📚 Niveau : intermédiaire
#   📝 Texte :
#   Chez d’autres, en revanche, un contact visuel forcé peut provoquer une réaction contraire, une surcharge céré- brale et un repli sur soi. Ainsi Donna Williams, l’auteur de Si on me touche, je n’existe plus, a expliqué qu’elle n’était capable d’utiliser qu’un seul canal sensoriel à la fois. Si une éd...
#   ---
#
# 🔍 Question : Qu'est-ce que la joie et comment la reconnaître chez soi ?
#
#   🔹 Résultat 1
#   📘 Source : Bienvenue dans mon monde - Paul El Kharrat
#   📄 Page : 101
#   🏷️ Thème : émotions
#   🎯 Type : personne
#   📚 Niveau : facile
#   📝 Texte :
#   Je suis content quand je rédige mes listes… Le bonheur, à mes yeux, c’est la capacité de se satisfaire de ce que l’on a et, chaque jour qui passe, de continuer à apprécier ce que l’on a obtenu, plutôt que de toujours chercher à avoir ce que l’on n’a pas. Pour l’insatisfait chronique que je suis, la...
#   ---
#
#   🔹 Résultat 2
#   📘 Source : Penser-en-images_9782738143129
#   📄 Page : 101
#   🏷️ Thème : émotions
#   🎯 Type : personne
#   📚 Niveau : complexe
#   📝 Texte :
#   C’est comme flotter sur un nuage. Je ressens quelque chose de semblable, quoique sous une forme plus légère, dans la machine à serrer. Je tire une grande satisfaction de mon travail intellectuel, mais je ne connais pas de joie extatique. Je sais qu’il me manque quelque chose quand les autres se pâme...
#   ---
#
#   🔹 Résultat 3
#   📘 Source : 100 idees pour enseigner les ha - Mehdi Liratni
#   📄 Page : 232
#   🏷️ Thème : émotions
#   🎯 Type : personne
#   📚 Niveau : complexe
#   📝 Texte :
#   IDÉE 100 HABILETÉS SOCIALES, RESPECT ET CONSIDÉRATION POUR LES AUTRES : UNE VOIE VERS LE BONHEUR… L’altruisme est une voie amenant directement au bonheur ! C’est prouvé scientifiquement (Ricard, 2004, 2014) ! Mais ne confondons pas plaisir et bonheur ! Un plaisir est une joie, une euphorie, voire un...
#   ---
#
# 🔍 Question : Comment se faire des amis quand on est timide ou différent ?
#
#   🔹 Résultat 1
#   📘 Source : Etre autiste et ado_ Strategies - Inconnu(e)
#   📄 Page : 184
#   🏷️ Thème : relations sociales
#   🎯 Type : exemple
#   📚 Niveau : intermédiaire
#   📝 Texte :
#   Lorsqu’il s’agit des amitiés, j’ai deux difficultés : me faire des amis et les garder. DIFFICULTÉ NUMÉRO 1 Me faire des amis Me faire des amis, je trouve ça compliqué, autant avec les neutotypiques qu’avec les autistes. À l’adolescence, on dirait que tout le monde a déjà des amis et je n’aime pas la...
#   ---
#
#   🔹 Résultat 2
#   📘 Source : Etre autiste et ado_ Strategies - Inconnu(e)
#   📄 Page : 188
#   🏷️ Thème : relations sociales
#   🎯 Type : exemple
#   📚 Niveau : intermédiaire
#   📝 Texte :
#   TRUCS POUR SE FAIRE DES AMIS Un bon moment pour se faire un ami, c’est la première fois que tu fréquentes un nouveau lieu ou que tu te trouves dans un nouveau contexte, parce que d’autres personnes sont également seules et disponibles pour de nouvelles amitiés. POUR ENTRER EN CONTACT AVEC QUELQU’UN ...
#   ---
#
#   🔹 Résultat 3
#   📘 Source : Etre autiste et ado_ Strategies - Inconnu(e)
#   📄 Page : 191
#   🏷️ Thème : relations sociales
#   🎯 Type : exemple
#   📚 Niveau : complexe
#   📝 Texte :
#   DIFFICULTÉ NUMÉRO 2 Garder mes amis La fréquence des contacts n’est pas une mesure d’amitié. Tu peux avoir une amitié très profonde avec quelqu’un que tu ne vois pas souvent. De même, tu peux parler avec quelqu’un tous les jours, par exemple la personne qui a un casier à côté du tien, sans que vous ...
#   ---
#
# 🔍 Question : Est-ce normal de ne pas comprendre les blagues ?
#
#   🔹 Résultat 1
#   📘 Source : 683956044-Le-Syndrome-dAsperger-Guide-Complet
#   📄 Page : 94
#   🏷️ Thème : autisme
#   🎯 Type : inconnu
#   📚 Niveau : facile
#   📝 Texte :
#   Les autres enfants sont conscients de la nature de la plaisanterie et du contexte approprié, et l’apprécient en conséquence. Les enfants Asperger peuvent répéter une plaisanterie grossière à succès, mais dans des circonstances...
#   ---
#
#   🔹 Résultat 2
#   📘 Source : 683956044-Le-Syndrome-dAsperger-Guide-Complet
#   📄 Page : 95
#   🏷️ Thème : relations sociales
#   🎯 Type : exemple
#   📚 Niveau : complexe
#   📝 Texte :
#   2001). Je connais beaucoup d’adolescents Asperger qui inventent de nombreuses plaisanteries, bien que parfois je ne sache pas bien ce qu’il y a de drôle. Pourtant, le rire de la personne Asperger suite à une plaisanterie unique en son genre est très contagieux. Les cercles concentriques L’enfant Asp...
#   ---
#
#   🔹 Résultat 3
#   📘 Source : 683956044-Le-Syndrome-dAsperger-Guide-Complet
#   📄 Page : 228
#   🏷️ Thème : inconnu
#   🎯 Type : inconnu
#   📚 Niveau : facile
#   📝 Texte :
#   Ses calembours ou blagues sont basés sur son intérêt et ne sont pas destinés à faire rire les autres pour un amusement collectif (Werth et al. 2001)....
#   ---

# %% [markdown]
# # Vectorstore FAISS

# %% [markdown]
# A présent, nous allons créer le vectorstore FAISS avec LangChain ce qui est necessaire pour l'utiliser dans le pipeline RAG. Le vectorstore FAISS est compatible avec LangChain et il permet d'utiliser ses fonctionnalités pour la recherche et la récupération d'informations. La création de vectorstore FAISS facilite également l'intégration avec d'autres composants de LangChain pour construire des applications de NLP avancées.

# %%
# Créer le vectorstore LangChain avec les documents et l'index FAISS sauvegardé pour l'utiliser dans le pipeline RAG

# Recréer les documents à partir des métadonnées enrichies
documents = [
    Document(
        page_content=row["text"],
        metadata={
            "chunk_id": row["chunk_id"],
            "source": row["source"],
            "page": row["page"],
            "theme": row["theme"],
            "niveau": row["niveau"],
            "type": row["type"]
        }
    )
    for _, row in df_meta.iterrows()
]

print(f"✅ {len(documents)} documents créés pour le vectorstore")
# Out:
# ✅ 6346 documents créés pour le vectorstore

# %%
# Importer les variables d'environnement (ici la clé API OpenAI)

load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
# Charger la clé API
embedding_function = OpenAIEmbeddings(openai_api_key=openai_api_key)

# Créer le vectorstore avec les embeddings pré-calculés et les documents pour le pipeline RAG
vectorstore = FAISS.from_documents(
    documents,
    embedding_function
)

# %%
# Sauvegarder le vectorstore pour l'utiliser dans le pipeline RAG

# 📁 Dossier de sauvegarde
vectorstore.save_local("../data/embeddings/faiss_store")
print("✅ Vectorstore sauvegardé avec .idx et .pkl")
# Out:
# ✅ Vectorstore sauvegardé avec .idx et .pkl
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Différence entre FAISS index et vectorstore:
#
# Ces deux termes sont liés, mais ils ne désignent pas exactement la même chose :
#
# FAISS index: c'est la structure de données optimisée pour la recherche de similarité entre vecteurs. [index.faiss stocke les vecteurs dans un format rapide à interroger].
#
# Vectorstore: c'est une abstraction LangChain qui combine le FAISS index + les chunks + les métadonnées.	[vectorstore = FAISS.load_local(...) te donne accès aux chunks et à leurs sources].
#
# En résumé : FAISS index = moteur brut, vectorstore = moteur + contenu + contexte.
