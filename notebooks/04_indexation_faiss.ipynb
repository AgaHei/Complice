# %% [markdown]
# # Indexation FAISS des embeddings OpenAI

# %%
# Importer les bibliothèques nécessaires
import faiss # Pour la recherche de similarité
import numpy as np # Pour les opérations numériques
import pandas as pd # Pour la manipulation des données
import pickle # Pour la sérialisation des objets
from openai import OpenAI # Pour interagir avec l'API OpenAI
import os # Pour les opérations sur les fichiers
from dotenv import load_dotenv # Pour charger les variables d'environnement (clés API)

# Charger les variables d'environnement
load_dotenv()

# Configuration de l'API OpenAI
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
print("Libraries importées avec succès!")
print(f"Version de FAISS: {faiss.__version__}")
print(f"Version de numpy: {np.__version__}")
print(f"Version de pandas: {pd.__version__}")

# Test de connexion OpenAI
try:
    # Tester avec un embedding simple
    response = client.embeddings.create(
        input="test",
        model="text-embedding-3-small"
    )
    print("✅ Connexion OpenAI réussie!")
    print(f"Dimension des embeddings OpenAI: {len(response.data[0].embedding)}")
except Exception as e:
    print(f"❌ Erreur connexion OpenAI: {e}")
# Out:
# Libraries importées avec succès!
# Version de FAISS: 1.12.0
# Version de numpy: 2.3.3
# Version de pandas: 2.3.2
# ✅ Connexion OpenAI réussie!
# Dimension des embeddings OpenAI: 1536
# ✅ Connexion OpenAI réussie!
# Dimension des embeddings OpenAI: 1536

# %%
# Charger les embeddings OpenAI générés dans le notebook 03
embeddings_file = "../data/embeddings/chunks_embeddings.npy"
metadata_file = "../data/embeddings/chunks_metadata.csv"

if os.path.exists(embeddings_file) and os.path.exists(metadata_file):
    # Charger les embeddings (array numpy)
    embeddings = np.load(embeddings_file)
    
    # Charger les métadonnées (DataFrame)
    df_metadata = pd.read_csv(metadata_file)
    documents = df_metadata["text"].tolist()
    
    print(f"✅ Embeddings chargés: {len(embeddings)} vecteurs")
    print(f"✅ Documents chargés: {len(documents)} textes")
    print(f"Dimension des embeddings: {embeddings.shape[1]}")
    
    # Vérifier la cohérence
    if len(embeddings) == len(documents):
        print("✅ Cohérence: nombre d'embeddings = nombre de documents")
    else:
        print(f"⚠️  Incohérence: {len(embeddings)} embeddings vs {len(documents)} documents")
        
else:
    missing_files = []
    if not os.path.exists(embeddings_file):
        missing_files.append(embeddings_file)
    if not os.path.exists(metadata_file):
        missing_files.append(metadata_file)
    
    print(f"❌ Fichier(s) non trouvé(s): {missing_files}")
    print("Veuillez d'abord exécuter le notebook 03_embedding.ipynb")
# Out:
# ✅ Embeddings chargés: 6346 vecteurs
# ✅ Documents chargés: 6346 textes
# Dimension des embeddings: 1536
# ✅ Cohérence: nombre d'embeddings = nombre de documents

# %% [markdown]
# ## Création de l'index FAISS pour les embeddings OpenAI (1536 dimensions)

# %%
# Convertir les embeddings en array numpy pour FAISS 
# (la recherche de similarité avec FAISS nécessite un array de type float32)

embeddings_array = np.array(embeddings, dtype='float32')

print(f"Shape des embeddings: {embeddings_array.shape}")
print(f"Type des données: {embeddings_array.dtype}")

# Vérification de la dimension (doit être 1536 pour OpenAI text-embedding-3-small)
expected_dim = 1536
actual_dim = embeddings_array.shape[1]

if actual_dim == expected_dim:
    print(f"✅ Dimension correcte: {actual_dim}")
else:
    print(f"❌ Dimension incorrecte: {actual_dim}, attendu: {expected_dim}")
    print("Veuillez régénérer les embeddings avec le bon modèle OpenAI")
# Out:
# Shape des embeddings: (6346, 1536)
# Type des données: float32
# ✅ Dimension correcte: 1536

# %% [markdown]
# ## Configuration de l'index FAISS

# %%
# Créer l'index FAISS pour les embeddings OpenAI (1536 dimensions)
dimension = 1536  # Dimension des embeddings OpenAI text-embedding-3-small
index = faiss.IndexFlatL2(dimension) # Utilisation de la distance L2 (euclidienne)

print(f"Index FAISS créé avec dimension: {dimension}")
print(f"Index vide, nombre de vecteurs: {index.ntotal}")
print(f"Index formé: {index.is_trained}")
# Out:
# Index FAISS créé avec dimension: 1536
# Index vide, nombre de vecteurs: 0
# Index formé: True

# %% [markdown]
# ## Ajout des embeddings à l'index

# %%
# Ajouter les embeddings à l'index FAISS
try:
    index.add(embeddings_array)
    print(f"✅ Embeddings ajoutés à l'index!")
    print(f"Nombre total de vecteurs dans l'index: {index.ntotal}")
    
    # Vérifications de base
    if index.ntotal == len(documents):
        print(f"✅ Cohérence: {index.ntotal} vecteurs pour {len(documents)} documents")
    else:
        print(f"❌ Incohérence: {index.ntotal} vecteurs pour {len(documents)} documents")
        
except Exception as e:
    print(f"❌ Erreur lors de l'ajout à l'index: {e}")
    print("Vérifiez que les dimensions correspondent (1536 pour OpenAI)")
    
# Test de recherche basique
print("\n--- Test de recherche basique ---")
try:
    # Utiliser le premier embedding comme requête de test
    test_query = embeddings_array[0:1]  # Reshaper pour la recherche
    distances, indices = index.search(test_query, k=3)
    print(f"✅ Test de recherche réussi!")
    print(f"Document le plus similaire (index {indices[0][0]}): {documents[indices[0][0]][:100]}...")
except Exception as e:
    print(f"❌ Erreur lors du test de recherche: {e}")
# Out:
# ✅ Embeddings ajoutés à l'index!
# Nombre total de vecteurs dans l'index: 6346
# ✅ Cohérence: 6346 vecteurs pour 6346 documents
#
# --- Test de recherche basique ---
# ✅ Test de recherche réussi!
# Document le plus similaire (index 0): Dr Mehdi Liratni Préface du Pr René Pry 100 IDÉES POUR ENSEIGNER LES HABILETÉS SOCIALES Agnes HEIJLI...

# %% [markdown]
# ## Sauvegarde de l'index FAISS et métadonnées

# %%
# Sauvegarder l'index FAISS
faiss_index_path = "../data/faiss_index_openai.index"
faiss.write_index(index, faiss_index_path)
print(f"✅ Index FAISS sauvegardé: {faiss_index_path}")

# Sauvegarder les métadonnées (documents et leurs indices)
metadata = {
    'documents': documents,
    'embedding_model': 'text-embedding-3-small',
    'embedding_dimension': 1536,
    'index_type': 'IndexFlatL2',
    'total_vectors': index.ntotal
}

metadata_path = "../data/faiss_metadata_openai.pkl"
with open(metadata_path, 'wb') as f:
    pickle.dump(metadata, f)
print(f"✅ Métadonnées sauvegardées: {metadata_path}")

# Résumé final
print(f"\n--- Résumé de l'indexation ---")
print(f"Modèle d'embedding: {metadata['embedding_model']}")
print(f"Dimension: {metadata['embedding_dimension']}")
print(f"Nombre de documents indexés: {metadata['total_vectors']}")
print(f"Type d'index: {metadata['index_type']}")

# Vérification des fichiers créés
print(f"\n--- Fichiers créés ---")
for file_path in [faiss_index_path, metadata_path]:
    if os.path.exists(file_path):
        size_mb = os.path.getsize(file_path) / (1024*1024)
        print(f"✅ {file_path} ({size_mb:.2f} MB)")
    else:
        print(f"❌ {file_path} - NON TROUVÉ")
# Out:
# ✅ Index FAISS sauvegardé: ../data/faiss_index_openai.index
# ✅ Métadonnées sauvegardées: ../data/faiss_metadata_openai.pkl
#
# --- Résumé de l'indexation ---
# Modèle d'embedding: text-embedding-3-small
# Dimension: 1536
# Nombre de documents indexés: 6346
# Type d'index: IndexFlatL2
#
# --- Fichiers créés ---
# ✅ ../data/faiss_index_openai.index (37.18 MB)
# ✅ ../data/faiss_metadata_openai.pkl (5.82 MB)

# %% [markdown]
# ## Test de l'index avec une vraie requête OpenAI

# %% [markdown]
# ### Test avec une nouvelle requête utilisateur

# %%
# Test avec une vraie requête utilisateur
def test_search_with_openai_query(query_text, k=5):
    """Test de recherche avec embedding OpenAI en temps réel"""
    print(f"Requête: '{query_text}'")
    
    try:
        # Générer l'embedding de la requête avec OpenAI
        response = client.embeddings.create(
            input=query_text,
            model="text-embedding-3-small"
        )
        query_embedding = np.array([response.data[0].embedding], dtype='float32')
        
        # Rechercher dans l'index
        distances, indices = index.search(query_embedding, k)
        
        print(f"\n--- Top {k} résultats ---")
        for i, (distance, idx) in enumerate(zip(distances[0], indices[0])):
            print(f"\n{i+1}. Distance: {distance:.4f}")
            print(f"   Document: {documents[idx][:200]}...")
            
        return distances, indices
        
    except Exception as e:
        print(f"❌ Erreur lors de la recherche: {e}")
        return None, None

# Test avec une requête d'exemple
test_query = "Pourquoi certaine personne évitent le contact visuel?"
distances, indices = test_search_with_openai_query(test_query)
# Out:
# Requête: 'Pourquoi certaine personne évitent le contact visuel?'
#
# --- Top 5 résultats ---
#
# 1. Distance: 0.8285
#    Document: Chez d’autres, en revanche, un contact visuel forcé peut provoquer une réaction contraire, une surcharge céré- brale et un repli sur soi. Ainsi Donna Williams, l’auteur de Si on me touche, je n’existe...
#
# 2. Distance: 0.8774
#    Document: IDÉE 14 REGARDE-MOI ! L’IMPORTANCE DU CONTACT VISUEL Un des premiers contacts sociaux « à distance » que l’enfant développe avec son entourage est le contact oculaire. Voyez comme le bébé, tout jeune ...
#
# 3. Distance: 0.8861
#    Document: Différent de l’intérêt plus grand pour les objets que pour les visages, il s’agit d’un évitement actif des visages. Une étude en IRMf de 2011, dont les résultats ont été publiés dans le Journal of Aut...
#
# 4. Distance: 0.9036
# ...

# %%
# Test avec une autre requête
test_query2 = "Pourquoi certaines personnes évitent le contact visuel?"
print("=" * 60)
distances2, indices2 = test_search_with_openai_query(test_query2, k=3)
# Out:
# ...
# Requête: 'Pourquoi certaines personnes évitent le contact visuel?'
#
# --- Top 3 résultats ---
#
# 1. Distance: 0.8169
#    Document: Chez d’autres, en revanche, un contact visuel forcé peut provoquer une réaction contraire, une surcharge céré- brale et un repli sur soi. Ainsi Donna Williams, l’auteur de Si on me touche, je n’existe...
#
# 2. Distance: 0.8606
#    Document: IDÉE 14 REGARDE-MOI ! L’IMPORTANCE DU CONTACT VISUEL Un des premiers contacts sociaux « à distance » que l’enfant développe avec son entourage est le contact oculaire. Voyez comme le bébé, tout jeune ...
#
# 3. Distance: 0.8640
#    Document: Différent de l’intérêt plus grand pour les objets que pour les visages, il s’agit d’un évitement actif des visages. Une étude en IRMf de 2011, dont les résultats ont été publiés dans le Journal of Aut...

# %%
# Fonction pour charger l'index sauvegardé (simulation de ce que fait rag_module.py)
def load_saved_index():
    """Charger l'index FAISS et les métadonnées sauvegardés"""
    try:
        # Charger l'index
        index_loaded = faiss.read_index("../data/faiss_index_openai.index")
        
        # Charger les métadonnées
        with open("../data/faiss_metadata_openai.pkl", 'rb') as f:
            metadata_loaded = pickle.load(f)
            
        print("✅ Index et métadonnées chargés avec succès!")
        print(f"Vecteurs dans l'index: {index_loaded.ntotal}")
        print(f"Modèle d'embedding: {metadata_loaded['embedding_model']}")
        print(f"Dimension: {metadata_loaded['embedding_dimension']}")
        
        return index_loaded, metadata_loaded
        
    except Exception as e:
        print(f"❌ Erreur lors du chargement: {e}")
        return None, None

# Test du chargement (comme dans rag_module.py)
loaded_index, loaded_metadata = load_saved_index()
# Out:
# ✅ Index et métadonnées chargés avec succès!
# Vecteurs dans l'index: 6346
# Modèle d'embedding: text-embedding-3-small
# Dimension: 1536

# %%
# Test final: simulation complète du pipeline RAG
if loaded_index is not None and loaded_metadata is not None:
    print("🎯 Test final du pipeline RAG complet")
    
    final_query = "Pourquoi certaines personnes évitent le contact visuel?"
    
    # Étape 1: Embedding de la requête
    response = client.embeddings.create(
        input=final_query,
        model="text-embedding-3-small"
    )
    query_vector = np.array([response.data[0].embedding], dtype='float32')
    
    # Étape 2: Recherche dans l'index
    distances, indices = loaded_index.search(query_vector, k=3)
    
    # Étape 3: Récupération des documents
    print(f"\nRequête: '{final_query}'")
    print(f"Top 3 documents les plus pertinents:")
    
    for i, (dist, idx) in enumerate(zip(distances[0], indices[0])):
        print(f"\n📄 Document {i+1} (distance: {dist:.4f}):")
        print(loaded_metadata['documents'][idx][:300] + "...")
        
    print("\n✅ Pipeline RAG OpenAI fonctionnel!")
# Out:
# 🎯 Test final du pipeline RAG complet
#
# Requête: 'Pourquoi certaines personnes évitent le contact visuel?'
# Top 3 documents les plus pertinents:
#
# 📄 Document 1 (distance: 0.8169):
# Chez d’autres, en revanche, un contact visuel forcé peut provoquer une réaction contraire, une surcharge céré- brale et un repli sur soi. Ainsi Donna Williams, l’auteur de Si on me touche, je n’existe plus, a expliqué qu’elle n’était capable d’utiliser qu’un seul canal sensoriel à la fois. Si une éd...
#
# 📄 Document 2 (distance: 0.8606):
# IDÉE 14 REGARDE-MOI ! L’IMPORTANCE DU CONTACT VISUEL Un des premiers contacts sociaux « à distance » que l’enfant développe avec son entourage est le contact oculaire. Voyez comme le bébé, tout jeune et malgré une pauvre vision néo-natale, peut intuitivement plonger son regard dans celui de sa maman...
#
# 📄 Document 3 (distance: 0.8640):
# ...

# %% [markdown]
# ## ✅ Résumé des corrections apportées
#
# Ce notebook a été adapté pour fonctionner avec les **embeddings OpenAI** au lieu de SentenceTransformers :
#
# ### Changements principaux :
# 1. **Modèle d'embedding** : Utilisation d'OpenAI `text-embedding-3-small` (1536 dimensions)
# 2. **Index FAISS** : Configuré pour les dimensions 1536 au lieu de 384
# 3. **Fichiers de sortie** : Nouveaux noms pour éviter les conflits (`faiss_index_openai.index`, `faiss_metadata_openai.pkl`)
# 4. **Tests en temps réel** : Génération d'embeddings OpenAI pour les requêtes de test
# 5. **Compatibilité** : Assure la cohérence avec `rag_module.py`
#
# ### Ordre d'exécution recommandé :
# 1. ✅ **Notebook 03** : Générer les embeddings OpenAI
# 2. ✅ **Notebook 04** : Créer l'index FAISS (ce notebook)
# 3. 🔄 **Notebooks 05-06** : Vérifier la compatibilité si nécessaire
# 4. 🚀 **Interface** : Utiliser le RAG avec les nouveaux embeddings
#
# > ⚠️ **Important** : Exécutez d'abord le notebook 03 pour générer les embeddings OpenAI avant d'exécuter ce notebook !
